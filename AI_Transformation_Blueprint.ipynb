# %% [markdown]
# <a href="https://colab.research.google.com/github/anu82sharma12/Consulting-Business-Intelligence-Frameworks/blob/main/AI_Transformation_Blueprint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

stages = ["Manual","Semi-Automated","AI-Driven"]
roi = [10,18,24]
plt.bar(stages, roi, color="purple")
plt.title("AI Transformation Blueprint – ROI Simulation")
plt.ylabel("ROI (%)"); plt.show()
