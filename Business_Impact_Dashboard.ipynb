# %% [markdown]
# <a href="https://colab.research.google.com/github/anu82sharma12/Consulting-Business-Intelligence-Frameworks/blob/main/Business_Impact_Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd
metrics = ["Revenue","Leads","Customer Retention","Ad Spend"]
before = np.random.randint(10,40,len(metrics))
after = before/2
df = pd.DataFrame({"Metric":metrics,"Latency_Before":before,"Latency_After":after})
print(df)
# Out:
#                Metric  Latency_Before  Latency_After
# 0             Revenue              15            7.5
# 1               Leads              22           11.0
# 2  Customer Retention              27           13.5
# 3            Ad Spend              10            5.0
