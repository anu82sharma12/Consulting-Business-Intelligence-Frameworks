# %% [markdown]
# <a href="https://colab.research.google.com/github/anu82sharma12/Consulting-Business-Intelligence-Frameworks/blob/main/Data_Driven_Strategy_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

np.random.seed(42)
scenarios = ["Baseline","Optimized_AI","Automated"]
time_taken = [100, 70, 65]
plt.bar(scenarios, time_taken, color=['grey','teal','orange'])
plt.title("Data-Driven Strategy Lab – Analysis Turnaround Time")
plt.ylabel("Time (mins)"); plt.show()
